# %%
import json

# %%
path = "./datasets/gqa/sceneGraphs/val_sceneGraphs.json"

# %%
with open(path) as file:
    data = json.load(file)

# %%
len(data.keys())
# Out:
# 10696

# %%
data.keys()
# Out:
# dict_keys(['2353884', '2320168', '2410049', '2375361', '2410046', '2320162', '2410041', '2343566', '2414600', '2372860', '2362812', '2414605', '1591973', '2315418', '2409694', '2379412', '2375145', '2370424', '2394854', '2325190', '2394852', '2375140', '2325195', '2378230', '2389015', '2378235', '1160007', '2317810', '1160003', '2413380', '1160009', '961', '286099', '2391519', '2374892', '2329750', '2335008', '2397582', '2346551', '2387230', '2406404', '2397589', '2382602', '2343077', '2347977', '2395984', '2324461', '2323656', '2352130', '2341787', '2357747', '2357744', '2343318', '2388232', '2343311', '2409036', '2370242', '2411391', '2411397', '2360094', '2353084', '2368088', '2367708', '2415552', '2352860', '2352862', '2361702', '2369283', '2369282', '2352686', '2352682', '2321343', '2411027', '2374237', '2395326', '2368884', '2415736', '2378416', '2365465', '2368881', '2347208', '2396982', '2338002', '2362816', '2318653', '2407116', '2383415', '2317105', '2385491', '2333659', '2
# ...

# %%
data["2353884"].keys()
# Out:
# dict_keys(['width', 'objects', 'height'])

# %%
data["2353884"]["objects"].keys()
# Out:
# dict_keys(['2716708', '2370325', '2747168', '3576182', '3100523', '2795769', '3576173', '2752960', '2449847', '1798567', '3576178', '3127901', '3127900', '2493560', '2077960', '3576175', '2237917', '1902903'])

# %%
data["2353884"]["objects"]["2716708"]
# Out:
# {'name': 'nose',
#  'h': 9,
#  'relations': [{'object': '2449847', 'name': 'of'},
#   {'object': '2493560', 'name': 'to the right of'},
#   {'object': '2370325', 'name': 'to the left of'}],
#  'w': 7,
#  'attributes': [],
#  'y': 54,
#  'x': 370}

# %%
data["2353884"]["objects"]["2449847"]
# Out:
# {'name': 'man',
#  'h': 228,
#  'relations': [{'object': '2795769', 'name': 'wearing'},
#   {'object': '3576178', 'name': 'wearing'},
#   {'object': '2747168', 'name': 'to the left of'},
#   {'object': '2077960', 'name': 'to the right of'},
#   {'object': '1902903', 'name': 'to the right of'}],
#  'w': 174,
#  'attributes': [],
#  'y': 33,
#  'x': 237}

# %%
path_txt = "./GraphVQA/meta_info/attr_gqa.txt"

with open(path_txt) as file:
    txt = file.readlines()

# %%
(txt)
# Out:
# ['<unk>\n',
#  'white\n',
#  'black\n',
#  'green\n',
#  'blue\n',
#  'brown\n',
#  'red\n',
#  'gray\n',
#  'large\n',
#  'small\n',
#  'wood\n',
#  'yellow\n',
#  'tall\n',
#  'metal\n',
#  'orange\n',
#  'long\n',
#  'dark\n',
#  'silver\n',
#  'pink\n',
#  'standing\n',
#  'clear\n',
#  'round\n',
#  'glass\n',
#  'open\n',
#  'sitting\n',
#  'short\n',
#  'parked\n',
#  'plastic\n',
#  'walking\n',
#  'brick\n',
#  'tan\n',
#  'purple\n',
#  'striped\n',
#  'colorful\n',
#  'cloudy\n',
#  'hanging\n',
#  'concrete\n',
#  'blond\n',
#  'bare\n',
#  'empty\n',
#  'young\n',
#  'old\n',
#  'closed\n',
#  'baseball\n',
#  'happy\n',
#  'bright\n',
#  'wet\n',
#  'gold\n',
#  'stone\n',
#  'smiling\n',
#  'light\n',
#  'dirty\n',
#  'flying\n',
#  'shiny\n',
#  'on\n',
#  'thin\n',
#  'square\n',
#  'tennis\n',
#  'little\n',
#  'sliced\n',
#  'leafy\n',
#  'playing\n',
#  'thick\n',
#  'beige\n',
#  'rectangular\n',
#  'calm\n',
#  'dry\n',
#  'tiled\n',
#  'leather\n',
# ...

# %%
with open("./GraphVQA/outputdir/dump_results.json") as file:
    data = json.load(file)

# %%
list(data.keys())
# Out:
# ['001000',
#  '0010008',
#  '001001',
#  '0010010',
#  '001001559',
#  '001001575',
#  '001001623',
#  '001001624',
#  '001001625',
#  '001001666',
#  '0010024',
#  '001002630',
#  '001002633',
#  '001002646',
#  '001002652',
#  '001002653',
#  '001002655',
#  '001002657',
#  '001002695',
#  '001002700',
#  '001002725',
#  '001002727',
#  '0010030',
#  '0010044',
#  '0010054',
#  '0010056',
#  '001006567',
#  '001006618',
#  '001006620',
#  '001006624',
#  '001006626',
#  '001006637',
#  '001006706',
#  '001006722',
#  '001006742',
#  '001006777',
#  '001006856',
#  '001006882',
#  '001006904',
#  '001006917',
#  '001006942',
#  '001006957',
#  '001006965',
#  '001006975',
#  '001006979',
#  '001006987',
#  '001006994',
#  '001007047',
#  '001007049',
#  '001007059',
#  '001007064',
#  '001007067',
#  '001007392',
#  '001007407',
#  '001007422',
#  '001007656',
#  '001007678',
#  '001007698',
#  '001007719',
#  '001009873',
#  '001009875',
#  '001009883',
#  '001009890',
# ...

# %%
(6805*93.23+95.45*5773)/12578
# Out:
# 94.24892669740818
